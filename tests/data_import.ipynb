# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from summit.data import solvent_ds

# %%
solvent_ds.xs('98-07-7', level='cas_number')
# Out:
#                                                                      molecular_weight  \
# stenutz_name             cosmo_name                chemical_formula
# (trichloromethyl)benzene (trichloromethyl)-benzene C7H5Cl3                        195
#
#                                                                      density  \
# stenutz_name             cosmo_name                chemical_formula
# (trichloromethyl)benzene (trichloromethyl)-benzene C7H5Cl3             1.173
#
#                                                                      molar_volume  \
# stenutz_name             cosmo_name                chemical_formula
# (trichloromethyl)benzene (trichloromethyl)-benzene C7H5Cl3                  166.6
#
#                                                                      refractive_index  \
# stenutz_name             cosmo_name                chemical_formula
# (trichloromethyl)benzene (trichloromethyl)-benzene C7H5Cl3                      1.557
#
# ...
